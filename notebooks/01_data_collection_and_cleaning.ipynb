# %% [markdown]
# # 01 - Data collection and cleaning
#
# This notebook documents initial data collection and basic cleaning steps.

# %%
# Example: load libraries
import pandas as pd
import numpy as np
